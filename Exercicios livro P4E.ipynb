# %% [markdown]
# # Capítulo 1 Por que você deveria aprender a programar?

# %% [markdown]
# ![image.png](attachment:50480313-6534-4dfd-b113-8ddf796acf31.png)

# %% [markdown]
# c)

# %% [markdown]
# ![image.png](attachment:42b47cc3-3b0e-4741-9bc7-459351d4d765.png)

# %% [markdown]
# #### 2-
# Um programa são as instruções construídas através de uma linguagem de programação que irão se comunicar com a CPU (após serem interpretadas por um compilador).
#
# #### 3-
# Um interpretador é a linguagem a qual o programador escreve, Python, C, C++, R, todos esses são interpretadores de alto nível que são capazes de serem interativos com o programador.
# O compilador recebe o código em linguagem de alto nível e traduz em linguagem de máquina, a partir daí a CPU é capaz de ler as várias sequências de zeros e um para executar as instruções.

# %% [markdown]
# ![image.png](attachment:8bbe6d63-e4a1-4ad4-aa58-cf46e5c74109.png)

# %% [markdown]
# #### 4-
# A resposta mais correta a (c), mas para ser mais exato, a linguagem de máquina está presente nos arquivos executáveis do windows por exemplo.

# %%
# 5- O correto seria:
print("Alô Mundo")
# Out:
# Alô Mundo

# %% [markdown]
# #### 6-
# b)

# %% [markdown]
# #### 7-
# b) 44

# %% [markdown]
# ![image.png](attachment:38f557ae-9c90-4034-a843-753fea0d86ab.png)

# %% [markdown]
# #### 8-
# Unidade Central de processamento (CPU): É a parte do computador que pergunta "E agora?", executa instruções em linguagem de máquina, e é o equivalente ao cérebro.
#
# Memória Principal: Armazena temporariamente informações que a CPU precisa com urgência, essa informação desaparece quando o computador é desligado. É equivalente a memória de curto prazo.
#
# Memória Secundária: É uma memória capaz de armazenar informações mesmo depois do computador ser desligado (ex.: HD, USB, CDs e DVDs). Ela é muito mais lenta que a memória principal e é o equivalente a memória de longo prazo dos seres humanos.
#
# Dispositivo de Entrada: São dispositivos conectados ao computador, como o teclado, microfones, mouse, touchpad etc. É o equivalente aos membrose órgãos sensoriais dos seres humanos.
#
# Dispositivos de saída: São também conectados ao computador, são os monitores, caixas de som, etc. São o equivalente a boca e o olho.
#
# #### 9-
# É necessário rever o código para ver se há falta de parênteses ou uso incorreto de aspas. No geral, são erros de gramática no python.

# %% [markdown]
# # Capítulo 2: Variáveis, expressões e declarações

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Resolução Exercício 1
5
x = 5
x+1
# Out:
# 6

# %% [markdown]
# ![image.png](attachment:f54388cd-5f52-4adb-b86f-d3c2f205c874.png)

# %%
nome = input("Digite seu nome:")
print("Olá", nome)
# Out:
# Digite seu nome: Carlos
# Olá Carlos

# %% [markdown]
# ![image.png](attachment:1d98d719-0588-460a-abcf-6311fd3e8275.png)

# %%
def pagamento(horas = input("Digite as horas:"), taxa = input("Digite a taxa:")):
    h = float(horas)
    t = float(taxa)
    valor = h * t
    print("Valor a ser pago", valor)

pagamento()
# Out:
# Digite as horas: 35
# Digite a taxa: 2.75
# Valor a ser pago 96.25

# %% [markdown]
# ![image.png](attachment:16ea0808-6c3b-40fd-a0de-d951e3755277.png)

# %%
largura = 17
altura = 12.0

a = largura//2
b = largura/2.0
c = altura/3
d = 1 + 2 * 5

print(a, type(a), "\n", b, type(b), "\n", c, type(c), "\n", d, type(d))
# Out:
# 8 <class 'int'>
#  8.5 <class 'float'>
#  4.0 <class 'float'>
#  11 <class 'int'>

# %% [markdown]
# ![image.png](attachment:0e80d040-520e-4e77-b7b5-a31b3043fa38.png)

# %%
celsius = input("Digite a temperatura em Celsius:")
fahrenheit = float(celsius) * 1.8 + 32
print(fahrenheit)
# Out:
# Digite a temperatura em Celsius: 20
# 68.0

# %% [markdown]
# # Capítulo 3: Execução Condicional

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def pagamento(horas = input("Digite as Horas:"), taxa = input("digite a taxa:")):
    h = float(horas)
    t = float(taxa)
    if h > 40:
        extra = (h - 40) * (1.5 * t)
        valor = (h - (h % 40)) * t + extra
        print("Pagamento:", valor)
    else:
        valor = h * t
        print("Pagamento:", valor)

pagamento()
# Out:
# Pagamento: 475.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def pagamento(horas = input("Digite as Horas:"), taxa = input("Digite as Taxas:")):
    try:
        h = float(horas)
        t = float(taxa)
        if h > 40:
            extra = (h - 40) * (1.5 * t)
            valor = 40 * t + extra
            print("Pagamento:", valor)
        else:
            valor = h * t
            print("Pagamento:", valor)
    except:
        print("Digite apenas números utilizando ponto (.) como demarcação de casas decimais!")

pagamento()
# Out:
# Digite apenas números utilizando ponto (.) como demarcação de casas decimais!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def nota(pts = input("Insira a pontuação obtida:")):
    try:
        p = float(pts)
        if p > 1.0:
            print("Insira uma pontuação dentro do intervalo 0.0 - 1.0")
        elif p >= 0.9:
            print("A")
        elif p >= 0.8:
            print("B")
        elif p >= 0.7:
            print("C")
        elif p >= 0.6:
            print("D")
        elif p < 0:
            print("Insira uma pontuação dentro do intervalo 0.0 - 1.0")
        elif p < 0.6:
            print("F")
    except:
        print("Pontuação Inválida")

nota()
# Out:
# Pontuação Inválida

# %% [markdown]
# # Capítulo 4 - Funções

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import random

for i in range(10):
    x = random.random()
    print(x)

# O gerador de números pseudo-aleatórios utiliza uma semente (seed) determinística, 
# geralmente baseada na hora do sistema, o que não oferece entropia suficiente para uma aleatoriedade verdadeiramente aleatória.
# Out:
# 0.39404612384546955
# 0.16127580823861043
# 0.4347856363593582
# 0.3907627090713608
# 0.7178859209980015
# 0.9760932107167373
# 0.7599632310198345
# 0.7923048084540062
# 0.43670682114223536
# 0.15675951006017752
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Resolução do Exercício 2

repeat_lyrics1()

def print_lyrics1():
    print("I'm a lumberjack, and I'm okay.")
    print('I sleep all night and I work all day.')

def repeat_lyrics1():
    print_lyrics1()
    print_lyrics1()

# name 'repeat_lyrics1' is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 # Resolução do Exercício 2
# ----> 3 repeat_lyrics1()
#       5 def print_lyrics1():
#       6     print("I'm a lumberjack, and I'm okay.")
#
# NameError: name 'repeat_lyrics1' is not defined

# %%
# Resolução do Exercício 3

def repeat_lyrics2():
    print_lyrics2()
    print_lyrics2()

def print_lyrics2():
    print("I'm a lumberjack, and I'm okay.")
    print('I sleep all night and I work all day.')


repeat_lyrics2()
# Out:
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# b) Ela indica o início de uma função

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# d)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def salario(horas = input("Insira as Horas:"), taxa = input("Insira o valor da Hora de Trabalho")):
    h = float(horas)
    t = float(taxa)
    if h > 40:
        extra = (h - 40.0) * (1.5 * t)
        pagamento = (h - (h % 40)) * t + extra
        print("Pagamento:", pagamento)
    elif h < 0:
        print("Insira um valor válido!")
    else:
        print("Pagamento", (h * t))
    
salario()
# Out:
# Pagamento: 475.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def comput(p = input("Insira a pontuação:")):
    try:
       p = float(p)
       if p > 1:
           print("Insira um valor válido.") 
       elif p >= 0.9:
          print("A")
       elif p >= 0.8:
          print("B")
       elif p >= 0.7:
          print("C")
       elif p >= 0.6:
          print("D")
       elif p < 0.6:
          print("F")
       elif p < 0:
          print("Insira um valor válido.")
    except:
       print("Insira um valor numérico entre 0 e 1")

comput()
# Out:
# A

# %% [markdown]
# # Capítulo 5 - Iteração

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = 0.0
tot = 0.0
while True:
    numero = input("Digite um número: ")
    if numero == "pronto":
        break
    try:
        n = float(numero)
    except:
        print("Entrada Inválida")
    print(n)
    num = num + 1
    tot = tot + n


print("Feito", "\n", tot, "\n", num, "\n", tot/num)
# Out:
# Entra Inválida
# 1.0
# 2.0
# Entra Inválida
# 2.0
# Entra Inválida
# 2.0
# 3.0
# 484.0
# 9999.0
# Feito
#  10493.0
#  7.0
#  1499.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
maximo = None
minimo = None

while True:
    numero = input("Digite um número")
    if numero == 'pronto':
        break
    try:
        n = float(numero)
        if maximo is None or n > maximo:
            maximo = n
        if minimo is None or n < minimo:
            minimo = n
        print("Máximo: ", maximo, "\n", "Mínimo: ", minimo)
    except:
        print("Insira uma entrada válida")

print(f"Ao fim o Máximo é: {maximo} \n E o Mínimo é: {minimo}")
# Out:
# Máximo:  1.0
#  Mínimo:  1.0
# Máximo:  2.0
#  Mínimo:  1.0
# Máximo:  3.0
#  Mínimo:  1.0
# Máximo:  3.0
#  Mínimo:  1.0
# Máximo:  4.0
#  Mínimo:  1.0
# Máximo:  5.0
#  Mínimo:  1.0
# Máximo:  99.0
#  Mínimo:  1.0
# Máximo:  99.0
#  Mínimo:  0.0
# Ao fim o Máximo é: 99.0
#  E o Mínimo é: 0.0

# %% [markdown]
# # Capítulo 6 - Strings

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Capítulo 7 - Arquivos

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Capítulo 8 - Listas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Capítulo 9 - Dicionários
